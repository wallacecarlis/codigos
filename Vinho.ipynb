# %% [markdown]
# <a href="https://colab.research.google.com/github/wallacecarlis/codigos/blob/master/Vinho.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
df = pd.read_csv("/content/winequality-red.csv")

# %%
df.head()
# Out:
#    fixed acidity  volatile acidity  citric acid  ...  sulphates  alcohol  quality
# 0            7.4              0.70         0.00  ...       0.56      9.4        5
# 1            7.8              0.88         0.00  ...       0.68      9.8        5
# 2            7.8              0.76         0.04  ...       0.65      9.8        5
# 3           11.2              0.28         0.56  ...       0.58      9.8        6
# 4            7.4              0.70         0.00  ...       0.56      9.4        5
#
# [5 rows x 12 columns]

# %%
df.describe()
# Out:
#        fixed acidity  volatile acidity  ...      alcohol      quality
# count    1599.000000       1599.000000  ...  1599.000000  1599.000000
# mean        8.319637          0.527821  ...    10.422983     5.636023
# std         1.741096          0.179060  ...     1.065668     0.807569
# min         4.600000          0.120000  ...     8.400000     3.000000
# 25%         7.100000          0.390000  ...     9.500000     5.000000
# 50%         7.900000          0.520000  ...    10.200000     6.000000
# 75%         9.200000          0.640000  ...    11.100000     6.000000
# max        15.900000          1.580000  ...    14.900000     8.000000
#
# [8 rows x 12 columns]

# %%
round(df.describe(), 2)
# Out:
#        fixed acidity  volatile acidity  ...  alcohol  quality
# count        1599.00           1599.00  ...  1599.00  1599.00
# mean            8.32              0.53  ...    10.42     5.64
# std             1.74              0.18  ...     1.07     0.81
# min             4.60              0.12  ...     8.40     3.00
# 25%             7.10              0.39  ...     9.50     5.00
# 50%             7.90              0.52  ...    10.20     6.00
# 75%             9.20              0.64  ...    11.10     6.00
# max            15.90              1.58  ...    14.90     8.00
#
# [8 rows x 12 columns]

# %%
df.plot.scatter("density", "pH");

# %%
df.hist();
